# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# # Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 889us/sample - loss: 229.3280 - y1_output_loss: 104.1833 - y2_output_loss: 123.1468 - y1_output_root_mean_squared_error: 10.2513 - y2_output_root_mean_squared_error: 11.1462 - val_loss: 41.4026 - val_y1_output_loss: 18.2980 - val_y2_output_loss: 22.9198 - val_y1_output_root_mean_squared_error: 4.3413 - val_y2_output_root_mean_squared_error: 4.7493
# Epoch 2/500
# 614/614 [==============================] - 0s 174us/sample - loss: 29.6406 - y1_output_loss: 12.0438 - y2_output_loss: 17.9107 - y1_output_root_mean_squared_error: 3.4721 - y2_output_root_mean_squared_error: 4.1934 - val_loss: 37.5313 - val_y1_output_loss: 13.3879 - val_y2_output_loss: 24.4485 - val_y1_output_root_mean_squared_error: 3.6846 - val_y2_output_root_mean_squared_error: 4.8944
# Epoch 3/500
# 614/614 [==============================] - 0s 137us/sample - loss: 24.7406 - y1_output_loss: 9.6969 - y2_output_loss: 14.9093 - y1_output_root_mean_squared_error: 3.1251 - y2_output_root_mean_squared_error: 3.8697 - val_loss: 26.9939 - val_y1_output_loss: 10.8431 - val_y2_output_loss: 15.8695 - val_y1_output_root_mean_squared_error: 3.3051 - val_y2_output_root_mean_squared_error: 4.0088
# Epoch 4/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.8141 - y1_output_loss: 8.7907 - y2_output_loss: 14.1496 - y1_output_root_mean_squared_error: 2.9634 - y2_output_root_mean_squared_error: 3.7460 - val_loss: 28.0763 - val_y1_output_loss: 11.4890 - val_y2_output_loss: 18.1241 - val_y1_output_root_mean_squared_error: 3.3208 - val_y2_output_root_mean_squared_error: 4.1290
# Epoch 5/500
# 614/614 [==============================] - 0s 144us/sample - loss: 24.5648 - y1_output_loss: 9.1104 - y2_output_loss: 15.4862 - y1_output_root_mean_squared_error: 3.0170 - y2_output_root_mean_squared_error: 3.9323 - val_loss: 35.8011 - val_y1_output_loss: 12.0352 - val_y2_output_loss: 23.1006 - val_y1_output_root_mean_squared_error: 3.4852 - val_y2_output_root_mean_squared_error: 4.8636
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.1987 - y1_output_loss: 9.0544 - y2_output_loss: 15.3037 - y1_output_root_mean_squared_error: 2.9760 - y2_output_root_mean_squared_error: 3.9169 - val_loss: 54.9903 - val_y1_output_loss: 19.7726 - val_y2_output_loss: 35.9391 - val_y1_output_root_mean_squared_error: 4.4259 - val_y2_output_root_mean_squared_error: 5.9499
# Epoch 7/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.9425 - y1_output_loss: 8.9077 - y2_output_loss: 15.4383 - y1_output_root_mean_squared_error: 2.9718 - y2_output_root_mean_squared_error: 3.8873 - val_loss: 86.4867 - val_y1_output_loss: 20.4713 - val_y2_output_loss: 69.4165 - val_y1_output_root_mean_squared_error: 4.4264 - val_y2_output_root_mean_squared_error: 8.1788
# Epoch 8/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.0381 - y1_output_loss: 8.3990 - y2_output_loss: 13.5406 - y1_output_root_mean_squared_error: 2.9056 - y2_output_root_mean_squared_error: 3.6872 - val_loss: 22.0556 - val_y1_output_loss: 9.6161 - val_y2_output_loss: 12.8680 - val_y1_output_root_mean_squared_error: 3.0810 - val_y2_output_root_mean_squared_error: 3.5445
# Epoch 9/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.0951 - y1_output_loss: 7.8845 - y2_output_loss: 12.0642 - y1_output_root_mean_squared_error: 2.8134 - y2_output_root_mean_squared_error: 3.4900 - val_loss: 53.3744 - val_y1_output_loss: 18.9558 - val_y2_output_loss: 33.1487 - val_y1_output_root_mean_squared_error: 4.4126 - val_y2_output_root_mean_squared_error: 5.8226
# Epoch 10/500
# 614/614 [==============================] - 0s 165us/sample - loss: 19.4044 - y1_output_loss: 7.4516 - y2_output_loss: 11.7760 - y1_output_root_mean_squared_error: 2.7418 - y2_output_root_mean_squared_error: 3.4477 - val_loss: 22.5013 - val_y1_output_loss: 9.9548 - val_y2_output_loss: 12.6932 - val_y1_output_root_mean_squared_error: 3.1485 - val_y2_output_root_mean_squared_error: 3.5480
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.9839 - y1_output_loss: 7.4176 - y2_output_loss: 11.4588 - y1_output_root_mean_squared_error: 2.7304 - y2_output_root_mean_squared_error: 3.3954 - val_loss: 22.3750 - val_y1_output_loss: 9.8088 - val_y2_output_loss: 12.8668 - val_y1_output_root_mean_squared_error: 3.0984 - val_y2_output_root_mean_squared_error: 3.5742
# Epoch 12/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.5939 - y1_output_loss: 7.9298 - y2_output_loss: 14.8566 - y1_output_root_mean_squared_error: 2.8075 - y2_output_root_mean_squared_error: 3.8356 - val_loss: 51.8326 - val_y1_output_loss: 14.3027 - val_y2_output_loss: 36.3182 - val_y1_output_root_mean_squared_error: 3.8350 - val_y2_output_root_mean_squared_error: 6.0931
# Epoch 13/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.2103 - y1_output_loss: 7.5680 - y2_output_loss: 12.6097 - y1_output_root_mean_squared_error: 2.7507 - y2_output_root_mean_squared_error: 3.5558 - val_loss: 22.5471 - val_y1_output_loss: 9.9387 - val_y2_output_loss: 12.5688 - val_y1_output_root_mean_squared_error: 3.1608 - val_y2_output_root_mean_squared_error: 3.5435
# Epoch 14/500
# 614/614 [==============================] - 0s 142us/sample - loss: 21.8608 - y1_output_loss: 7.9997 - y2_output_loss: 14.2668 - y1_output_root_mean_squared_error: 2.7893 - y2_output_root_mean_squared_error: 3.7524 - val_loss: 96.2341 - val_y1_output_loss: 24.2291 - val_y2_output_loss: 70.5125 - val_y1_output_root_mean_squared_error: 4.9815 - val_y2_output_root_mean_squared_error: 8.4510
# Epoch 15/500
# 614/614 [==============================] - 0s 137us/sample - loss: 20.5844 - y1_output_loss: 7.7442 - y2_output_loss: 12.7105 - y1_output_root_mean_squared_error: 2.7898 - y2_output_root_mean_squared_error: 3.5779 - val_loss: 19.7170 - val_y1_output_loss: 8.8063 - val_y2_output_loss: 11.1816 - val_y1_output_root_mean_squared_error: 2.9559 - val_y2_output_root_mean_squared_error: 3.3136
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.0033 - y1_output_loss: 7.3269 - y2_output_loss: 13.6021 - y1_output_root_mean_squared_error: 2.7001 - y2_output_root_mean_squared_error: 3.7030 - val_loss: 22.6789 - val_y1_output_loss: 8.6726 - val_y2_output_loss: 13.8356 - val_y1_output_root_mean_squared_error: 2.9402 - val_y2_output_root_mean_squared_error: 3.7462
# Epoch 17/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.7865 - y1_output_loss: 7.0553 - y2_output_loss: 11.8215 - y1_output_root_mean_squared_error: 2.6646 - y2_output_root_mean_squared_error: 3.4186 - val_loss: 29.5713 - val_y1_output_loss: 8.6207 - val_y2_output_loss: 20.6210 - val_y1_output_root_mean_squared_error: 2.9383 - val_y2_output_root_mean_squared_error: 4.5758
# Epoch 18/500
# 614/614 [==============================] - 0s 149us/sample - loss: 18.6440 - y1_output_loss: 7.2906 - y2_output_loss: 11.6150 - y1_output_root_mean_squared_error: 2.6943 - y2_output_root_mean_squared_error: 3.3741 - val_loss: 132.2034 - val_y1_output_loss: 21.7128 - val_y2_output_loss: 113.2716 - val_y1_output_root_mean_squared_error: 4.5852 - val_y2_output_root_mean_squared_error: 10.5442
# Epoch 19/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.8606 - y1_output_loss: 6.9759 - y2_output_loss: 13.7616 - y1_output_root_mean_squared_error: 2.6506 - y2_output_root_mean_squared_error: 3.7195 - val_loss: 21.1599 - val_y1_output_loss: 8.6379 - val_y2_output_loss: 13.3350 - val_y1_output_root_mean_squared_error: 2.8971 - val_y2_output_root_mean_squared_error: 3.5730
# Epoch 20/500
# 614/614 [==============================] - 0s 135us/sample - loss: 17.6953 - y1_output_loss: 6.6592 - y2_output_loss: 11.3455 - y1_output_root_mean_squared_error: 2.5655 - y2_output_root_mean_squared_error: 3.3337 - val_loss: 33.0735 - val_y1_output_loss: 9.5619 - val_y2_output_loss: 25.0040 - val_y1_output_root_mean_squared_error: 3.0229 - val_y2_output_root_mean_squared_error: 4.8924
# Epoch 21/500
# 614/614 [==============================] - 0s 142us/sample - loss: 16.1389 - y1_output_loss: 6.0087 - y2_output_loss: 10.0000 - y1_output_root_mean_squared_error: 2.4619 - y2_output_root_mean_squared_error: 3.1746 - val_loss: 18.4946 - val_y1_output_loss: 8.3518 - val_y2_output_loss: 11.1349 - val_y1_output_root_mean_squared_error: 2.8134 - val_y2_output_root_mean_squared_error: 3.2526
# Epoch 22/500
# 614/614 [==============================] - 0s 146us/sample - loss: 15.2348 - y1_output_loss: 5.8467 - y2_output_loss: 9.2728 - y1_output_root_mean_squared_error: 2.4276 - y2_output_root_mean_squared_error: 3.0564 - val_loss: 17.6708 - val_y1_output_loss: 7.7212 - val_y2_output_loss: 10.5409 - val_y1_output_root_mean_squared_error: 2.7354 - val_y2_output_root_mean_squared_error: 3.1919
# Epoch 23/500
# 614/614 [==============================] - 0s 150us/sample - loss: 15.7898 - y1_output_loss: 5.9205 - y2_output_loss: 9.7917 - y1_output_root_mean_squared_error: 2.4352 - y2_output_root_mean_squared_error: 3.1400 - val_loss: 18.0266 - val_y1_output_loss: 7.2056 - val_y2_output_loss: 11.1066 - val_y1_output_root_mean_squared_error: 2.6345 - val_y2_output_root_mean_squared_error: 3.3296
# Epoch 24/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.4255 - y1_output_loss: 5.5064 - y2_output_loss: 8.7963 - y1_output_root_mean_squared_error: 2.3573 - y2_output_root_mean_squared_error: 2.9780 - val_loss: 15.1892 - val_y1_output_loss: 6.4731 - val_y2_output_loss: 8.9447 - val_y1_output_root_mean_squared_error: 2.5252 - val_y2_output_root_mean_squared_error: 2.9686
# Epoch 25/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.7067 - y1_output_loss: 5.0934 - y2_output_loss: 7.6337 - y1_output_root_mean_squared_error: 2.2585 - y2_output_root_mean_squared_error: 2.7579 - val_loss: 15.8994 - val_y1_output_loss: 6.9867 - val_y2_output_loss: 9.2619 - val_y1_output_root_mean_squared_error: 2.6185 - val_y2_output_root_mean_squared_error: 3.0072
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 13.2491 - y1_output_loss: 4.9369 - y2_output_loss: 8.2061 - y1_output_root_mean_squared_error: 2.2315 - y2_output_root_mean_squared_error: 2.8757 - val_loss: 14.9734 - val_y1_output_loss: 6.0485 - val_y2_output_loss: 9.2922 - val_y1_output_root_mean_squared_error: 2.4418 - val_y2_output_root_mean_squared_error: 3.0019
# Epoch 27/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.7396 - y1_output_loss: 5.1086 - y2_output_loss: 8.5028 - y1_output_root_mean_squared_error: 2.2706 - y2_output_root_mean_squared_error: 2.9298 - val_loss: 16.6771 - val_y1_output_loss: 6.8102 - val_y2_output_loss: 10.2756 - val_y1_output_root_mean_squared_error: 2.5744 - val_y2_output_root_mean_squared_error: 3.1701
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.9232 - y1_output_loss: 4.9588 - y2_output_loss: 7.9598 - y1_output_root_mean_squared_error: 2.2236 - y2_output_root_mean_squared_error: 2.8247 - val_loss: 15.9594 - val_y1_output_loss: 6.5627 - val_y2_output_loss: 10.2611 - val_y1_output_root_mean_squared_error: 2.5007 - val_y2_output_root_mean_squared_error: 3.1154
# Epoch 29/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.3739 - y1_output_loss: 4.9718 - y2_output_loss: 8.2838 - y1_output_root_mean_squared_error: 2.2403 - y2_output_root_mean_squared_error: 2.8905 - val_loss: 14.9953 - val_y1_output_loss: 6.2070 - val_y2_output_loss: 8.9047 - val_y1_output_root_mean_squared_error: 2.4837 - val_y2_output_root_mean_squared_error: 2.9710
# Epoch 30/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.5608 - y1_output_loss: 5.4305 - y2_output_loss: 10.0498 - y1_output_root_mean_squared_error: 2.3296 - y2_output_root_mean_squared_error: 3.1834 - val_loss: 15.1894 - val_y1_output_loss: 6.5049 - val_y2_output_loss: 9.0421 - val_y1_output_root_mean_squared_error: 2.5224 - val_y2_output_root_mean_squared_error: 2.9710
# Epoch 31/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.8678 - y1_output_loss: 4.5859 - y2_output_loss: 7.2884 - y1_output_root_mean_squared_error: 2.1421 - y2_output_root_mean_squared_error: 2.6980 - val_loss: 15.0342 - val_y1_output_loss: 6.4886 - val_y2_output_loss: 9.2504 - val_y1_output_root_mean_squared_error: 2.4899 - val_y2_output_root_mean_squared_error: 2.9723
# Epoch 32/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.8371 - y1_output_loss: 4.7032 - y2_output_loss: 7.0608 - y1_output_root_mean_squared_error: 2.1759 - y2_output_root_mean_squared_error: 2.6650 - val_loss: 16.7713 - val_y1_output_loss: 6.7355 - val_y2_output_loss: 9.9248 - val_y1_output_root_mean_squared_error: 2.6033 - val_y2_output_root_mean_squared_error: 3.1613
# Epoch 33/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.0380 - y1_output_loss: 4.0581 - y2_output_loss: 6.9253 - y1_output_root_mean_squared_error: 2.0199 - y2_output_root_mean_squared_error: 2.6378 - val_loss: 19.2722 - val_y1_output_loss: 7.5149 - val_y2_output_loss: 11.3236 - val_y1_output_root_mean_squared_error: 2.7728 - val_y2_output_root_mean_squared_error: 3.4035
# Epoch 34/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.7567 - y1_output_loss: 4.8641 - y2_output_loss: 7.9810 - y1_output_root_mean_squared_error: 2.1788 - y2_output_root_mean_squared_error: 2.8301 - val_loss: 12.7160 - val_y1_output_loss: 5.2167 - val_y2_output_loss: 7.7138 - val_y1_output_root_mean_squared_error: 2.2629 - val_y2_output_root_mean_squared_error: 2.7560
# Epoch 35/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.0950 - y1_output_loss: 3.9489 - y2_output_loss: 6.1023 - y1_output_root_mean_squared_error: 1.9926 - y2_output_root_mean_squared_error: 2.4748 - val_loss: 18.5228 - val_y1_output_loss: 6.1307 - val_y2_output_loss: 12.3584 - val_y1_output_root_mean_squared_error: 2.4730 - val_y2_output_root_mean_squared_error: 3.5224
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.7752 - y1_output_loss: 4.0166 - y2_output_loss: 6.6732 - y1_output_root_mean_squared_error: 2.0131 - y2_output_root_mean_squared_error: 2.5928 - val_loss: 15.8034 - val_y1_output_loss: 5.8068 - val_y2_output_loss: 10.0081 - val_y1_output_root_mean_squared_error: 2.4099 - val_y2_output_root_mean_squared_error: 3.1616
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.5195 - y1_output_loss: 3.6636 - y2_output_loss: 5.8356 - y1_output_root_mean_squared_error: 1.9054 - y2_output_root_mean_squared_error: 2.4267 - val_loss: 12.2966 - val_y1_output_loss: 5.1222 - val_y2_output_loss: 7.2760 - val_y1_output_root_mean_squared_error: 2.2438 - val_y2_output_root_mean_squared_error: 2.6948
# Epoch 38/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.1159 - y1_output_loss: 3.7590 - y2_output_loss: 7.3257 - y1_output_root_mean_squared_error: 1.9434 - y2_output_root_mean_squared_error: 2.7090 - val_loss: 14.3055 - val_y1_output_loss: 6.0165 - val_y2_output_loss: 8.9784 - val_y1_output_root_mean_squared_error: 2.4078 - val_y2_output_root_mean_squared_error: 2.9168
# Epoch 39/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.9319 - y1_output_loss: 3.4972 - y2_output_loss: 6.3449 - y1_output_root_mean_squared_error: 1.8780 - y2_output_root_mean_squared_error: 2.5308 - val_loss: 11.0446 - val_y1_output_loss: 4.4955 - val_y2_output_loss: 6.8184 - val_y1_output_root_mean_squared_error: 2.1021 - val_y2_output_root_mean_squared_error: 2.5740
# Epoch 40/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.9922 - y1_output_loss: 3.5886 - y2_output_loss: 6.3152 - y1_output_root_mean_squared_error: 1.9027 - y2_output_root_mean_squared_error: 2.5243 - val_loss: 11.7367 - val_y1_output_loss: 4.8597 - val_y2_output_loss: 7.2533 - val_y1_output_root_mean_squared_error: 2.1608 - val_y2_output_root_mean_squared_error: 2.6585
# Epoch 41/500
# 614/614 [==============================] - 0s 149us/sample - loss: 11.0851 - y1_output_loss: 3.8710 - y2_output_loss: 7.2328 - y1_output_root_mean_squared_error: 1.9665 - y2_output_root_mean_squared_error: 2.6867 - val_loss: 12.1880 - val_y1_output_loss: 4.7224 - val_y2_output_loss: 7.8006 - val_y1_output_root_mean_squared_error: 2.1384 - val_y2_output_root_mean_squared_error: 2.7596
# Epoch 42/500
# 614/614 [==============================] - 0s 141us/sample - loss: 11.0180 - y1_output_loss: 3.6978 - y2_output_loss: 7.2937 - y1_output_root_mean_squared_error: 1.9187 - y2_output_root_mean_squared_error: 2.7086 - val_loss: 10.2367 - val_y1_output_loss: 4.0438 - val_y2_output_loss: 6.5449 - val_y1_output_root_mean_squared_error: 1.9811 - val_y2_output_root_mean_squared_error: 2.5124
# Epoch 43/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.9222 - y1_output_loss: 3.4847 - y2_output_loss: 6.4453 - y1_output_root_mean_squared_error: 1.8700 - y2_output_root_mean_squared_error: 2.5348 - val_loss: 21.8842 - val_y1_output_loss: 5.5150 - val_y2_output_loss: 17.4559 - val_y1_output_root_mean_squared_error: 2.2768 - val_y2_output_root_mean_squared_error: 4.0866
# Epoch 44/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.3755 - y1_output_loss: 3.5638 - y2_output_loss: 6.8755 - y1_output_root_mean_squared_error: 1.8847 - y2_output_root_mean_squared_error: 2.6122 - val_loss: 22.9782 - val_y1_output_loss: 6.5918 - val_y2_output_loss: 16.1070 - val_y1_output_root_mean_squared_error: 2.5867 - val_y2_output_root_mean_squared_error: 4.0358
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.9855 - y1_output_loss: 3.0332 - y2_output_loss: 4.8860 - y1_output_root_mean_squared_error: 1.7497 - y2_output_root_mean_squared_error: 2.2191 - val_loss: 9.5345 - val_y1_output_loss: 3.6092 - val_y2_output_loss: 6.1351 - val_y1_output_root_mean_squared_error: 1.8813 - val_y2_output_root_mean_squared_error: 2.4485
# Epoch 46/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.4074 - y1_output_loss: 2.8265 - y2_output_loss: 5.5193 - y1_output_root_mean_squared_error: 1.6843 - y2_output_root_mean_squared_error: 2.3602 - val_loss: 17.5588 - val_y1_output_loss: 6.4893 - val_y2_output_loss: 11.3050 - val_y1_output_root_mean_squared_error: 2.5385 - val_y2_output_root_mean_squared_error: 3.3339
# Epoch 47/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.1919 - y1_output_loss: 3.3630 - y2_output_loss: 5.7629 - y1_output_root_mean_squared_error: 1.8402 - y2_output_root_mean_squared_error: 2.4095 - val_loss: 9.5763 - val_y1_output_loss: 3.4645 - val_y2_output_loss: 6.1758 - val_y1_output_root_mean_squared_error: 1.8530 - val_y2_output_root_mean_squared_error: 2.4785
# Epoch 48/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.4512 - y1_output_loss: 3.5052 - y2_output_loss: 7.8732 - y1_output_root_mean_squared_error: 1.8799 - y2_output_root_mean_squared_error: 2.8138 - val_loss: 11.5134 - val_y1_output_loss: 3.5979 - val_y2_output_loss: 8.3747 - val_y1_output_root_mean_squared_error: 1.8566 - val_y2_output_root_mean_squared_error: 2.8401
# Epoch 49/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.4448 - y1_output_loss: 2.5715 - y2_output_loss: 5.0008 - y1_output_root_mean_squared_error: 1.5994 - y2_output_root_mean_squared_error: 2.2106 - val_loss: 9.7074 - val_y1_output_loss: 3.6185 - val_y2_output_loss: 5.9562 - val_y1_output_root_mean_squared_error: 1.9176 - val_y2_output_root_mean_squared_error: 2.4557
# Epoch 50/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.7277 - y1_output_loss: 2.6523 - y2_output_loss: 5.0405 - y1_output_root_mean_squared_error: 1.6329 - y2_output_root_mean_squared_error: 2.2498 - val_loss: 12.1070 - val_y1_output_loss: 3.6648 - val_y2_output_loss: 9.0305 - val_y1_output_root_mean_squared_error: 1.8619 - val_y2_output_root_mean_squared_error: 2.9395
# Epoch 51/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.5875 - y1_output_loss: 2.7430 - y2_output_loss: 4.8590 - y1_output_root_mean_squared_error: 1.6498 - y2_output_root_mean_squared_error: 2.2058 - val_loss: 15.3554 - val_y1_output_loss: 3.5472 - val_y2_output_loss: 11.7624 - val_y1_output_root_mean_squared_error: 1.8893 - val_y2_output_root_mean_squared_error: 3.4331
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.1319 - y1_output_loss: 2.7260 - y2_output_loss: 5.3867 - y1_output_root_mean_squared_error: 1.6529 - y2_output_root_mean_squared_error: 2.3237 - val_loss: 17.1473 - val_y1_output_loss: 4.6840 - val_y2_output_loss: 13.0444 - val_y1_output_root_mean_squared_error: 2.1185 - val_y2_output_root_mean_squared_error: 3.5580
# Epoch 53/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.7124 - y1_output_loss: 2.8874 - y2_output_loss: 5.8455 - y1_output_root_mean_squared_error: 1.7070 - y2_output_root_mean_squared_error: 2.4080 - val_loss: 13.4811 - val_y1_output_loss: 3.8958 - val_y2_output_loss: 10.2146 - val_y1_output_root_mean_squared_error: 1.9196 - val_y2_output_root_mean_squared_error: 3.1299
# Epoch 54/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.9902 - y1_output_loss: 2.4618 - y2_output_loss: 4.5236 - y1_output_root_mean_squared_error: 1.5740 - y2_output_root_mean_squared_error: 2.1244 - val_loss: 8.9332 - val_y1_output_loss: 3.2374 - val_y2_output_loss: 5.9486 - val_y1_output_root_mean_squared_error: 1.7661 - val_y2_output_root_mean_squared_error: 2.4112
# Epoch 55/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7650 - y1_output_loss: 2.3190 - y2_output_loss: 4.6011 - y1_output_root_mean_squared_error: 1.4942 - y2_output_root_mean_squared_error: 2.1289 - val_loss: 22.4761 - val_y1_output_loss: 8.0819 - val_y2_output_loss: 13.7751 - val_y1_output_root_mean_squared_error: 2.8865 - val_y2_output_root_mean_squared_error: 3.7609
# Epoch 56/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.1188 - y1_output_loss: 2.7035 - y2_output_loss: 5.3476 - y1_output_root_mean_squared_error: 1.6512 - y2_output_root_mean_squared_error: 2.3222 - val_loss: 8.1118 - val_y1_output_loss: 2.7068 - val_y2_output_loss: 5.6711 - val_y1_output_root_mean_squared_error: 1.6137 - val_y2_output_root_mean_squared_error: 2.3469
# Epoch 57/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.3790 - y1_output_loss: 2.1306 - y2_output_loss: 4.1901 - y1_output_root_mean_squared_error: 1.4663 - y2_output_root_mean_squared_error: 2.0565 - val_loss: 8.5689 - val_y1_output_loss: 3.0170 - val_y2_output_loss: 5.5406 - val_y1_output_root_mean_squared_error: 1.7405 - val_y2_output_root_mean_squared_error: 2.3536
# Epoch 58/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.3016 - y1_output_loss: 2.0454 - y2_output_loss: 4.2213 - y1_output_root_mean_squared_error: 1.4310 - y2_output_root_mean_squared_error: 2.0625 - val_loss: 7.9073 - val_y1_output_loss: 2.6371 - val_y2_output_loss: 5.3552 - val_y1_output_root_mean_squared_error: 1.5976 - val_y2_output_root_mean_squared_error: 2.3141
# Epoch 59/500
# 614/614 [==============================] - 0s 150us/sample - loss: 10.4938 - y1_output_loss: 3.2232 - y2_output_loss: 7.1910 - y1_output_root_mean_squared_error: 1.8038 - y2_output_root_mean_squared_error: 2.6908 - val_loss: 22.8504 - val_y1_output_loss: 5.9676 - val_y2_output_loss: 17.8419 - val_y1_output_root_mean_squared_error: 2.3707 - val_y2_output_root_mean_squared_error: 4.1509
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.3557 - y1_output_loss: 2.6268 - y2_output_loss: 5.6586 - y1_output_root_mean_squared_error: 1.6276 - y2_output_root_mean_squared_error: 2.3888 - val_loss: 10.0824 - val_y1_output_loss: 3.5277 - val_y2_output_loss: 6.5330 - val_y1_output_root_mean_squared_error: 1.8853 - val_y2_output_root_mean_squared_error: 2.5550
# Epoch 61/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.8467 - y1_output_loss: 2.0240 - y2_output_loss: 3.8090 - y1_output_root_mean_squared_error: 1.4267 - y2_output_root_mean_squared_error: 1.9522 - val_loss: 10.2031 - val_y1_output_loss: 3.3143 - val_y2_output_loss: 6.7617 - val_y1_output_root_mean_squared_error: 1.8385 - val_y2_output_root_mean_squared_error: 2.6121
# Epoch 62/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.6520 - y1_output_loss: 2.4401 - y2_output_loss: 5.1388 - y1_output_root_mean_squared_error: 1.5695 - y2_output_root_mean_squared_error: 2.2778 - val_loss: 8.1930 - val_y1_output_loss: 2.9450 - val_y2_output_loss: 5.1164 - val_y1_output_root_mean_squared_error: 1.7284 - val_y2_output_root_mean_squared_error: 2.2816
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.0706 - y1_output_loss: 2.0727 - y2_output_loss: 3.9862 - y1_output_root_mean_squared_error: 1.4417 - y2_output_root_mean_squared_error: 1.9980 - val_loss: 7.5693 - val_y1_output_loss: 2.5677 - val_y2_output_loss: 5.3567 - val_y1_output_root_mean_squared_error: 1.5637 - val_y2_output_root_mean_squared_error: 2.2637
# Epoch 64/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.5578 - y1_output_loss: 1.8191 - y2_output_loss: 3.8366 - y1_output_root_mean_squared_error: 1.3458 - y2_output_root_mean_squared_error: 1.9356 - val_loss: 12.5416 - val_y1_output_loss: 3.8667 - val_y2_output_loss: 8.5734 - val_y1_output_root_mean_squared_error: 1.9807 - val_y2_output_root_mean_squared_error: 2.9357
# Epoch 65/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.9356 - y1_output_loss: 1.8969 - y2_output_loss: 4.0483 - y1_output_root_mean_squared_error: 1.3660 - y2_output_root_mean_squared_error: 2.0173 - val_loss: 7.7321 - val_y1_output_loss: 2.4509 - val_y2_output_loss: 5.1339 - val_y1_output_root_mean_squared_error: 1.5728 - val_y2_output_root_mean_squared_error: 2.2931
# Epoch 66/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.8778 - y1_output_loss: 1.9954 - y2_output_loss: 3.8501 - y1_output_root_mean_squared_error: 1.4117 - y2_output_root_mean_squared_error: 1.9710 - val_loss: 8.3680 - val_y1_output_loss: 2.8568 - val_y2_output_loss: 5.9103 - val_y1_output_root_mean_squared_error: 1.6384 - val_y2_output_root_mean_squared_error: 2.3841
# Epoch 67/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.3833 - y1_output_loss: 1.7066 - y2_output_loss: 3.6565 - y1_output_root_mean_squared_error: 1.3055 - y2_output_root_mean_squared_error: 1.9181 - val_loss: 7.0932 - val_y1_output_loss: 1.8882 - val_y2_output_loss: 5.1933 - val_y1_output_root_mean_squared_error: 1.3736 - val_y2_output_root_mean_squared_error: 2.2817
# Epoch 68/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.6789 - y1_output_loss: 1.9251 - y2_output_loss: 3.7381 - y1_output_root_mean_squared_error: 1.3928 - y2_output_root_mean_squared_error: 1.9337 - val_loss: 7.4756 - val_y1_output_loss: 1.9856 - val_y2_output_loss: 5.5823 - val_y1_output_root_mean_squared_error: 1.4118 - val_y2_output_root_mean_squared_error: 2.3415
# Epoch 69/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.6221 - y1_output_loss: 1.7149 - y2_output_loss: 3.9136 - y1_output_root_mean_squared_error: 1.3119 - y2_output_root_mean_squared_error: 1.9751 - val_loss: 7.1499 - val_y1_output_loss: 2.0330 - val_y2_output_loss: 5.2327 - val_y1_output_root_mean_squared_error: 1.4172 - val_y2_output_root_mean_squared_error: 2.2675
# Epoch 70/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.0135 - y1_output_loss: 1.7364 - y2_output_loss: 4.3251 - y1_output_root_mean_squared_error: 1.3138 - y2_output_root_mean_squared_error: 2.0706 - val_loss: 13.4878 - val_y1_output_loss: 2.5326 - val_y2_output_loss: 11.3664 - val_y1_output_root_mean_squared_error: 1.5582 - val_y2_output_root_mean_squared_error: 3.3256
# Epoch 71/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.3783 - y1_output_loss: 1.7864 - y2_output_loss: 3.5722 - y1_output_root_mean_squared_error: 1.3321 - y2_output_root_mean_squared_error: 1.8984 - val_loss: 8.6662 - val_y1_output_loss: 2.9391 - val_y2_output_loss: 5.5387 - val_y1_output_root_mean_squared_error: 1.7418 - val_y2_output_root_mean_squared_error: 2.3732
# Epoch 72/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.6388 - y1_output_loss: 1.7872 - y2_output_loss: 3.8095 - y1_output_root_mean_squared_error: 1.3419 - y2_output_root_mean_squared_error: 1.9591 - val_loss: 6.3602 - val_y1_output_loss: 1.9718 - val_y2_output_loss: 4.5818 - val_y1_output_root_mean_squared_error: 1.3888 - val_y2_output_root_mean_squared_error: 2.1051
# Epoch 73/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.7921 - y1_output_loss: 1.5178 - y2_output_loss: 3.2905 - y1_output_root_mean_squared_error: 1.2324 - y2_output_root_mean_squared_error: 1.8092 - val_loss: 11.3748 - val_y1_output_loss: 2.3606 - val_y2_output_loss: 9.2091 - val_y1_output_root_mean_squared_error: 1.5187 - val_y2_output_root_mean_squared_error: 3.0114
# Epoch 74/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.8226 - y1_output_loss: 1.4921 - y2_output_loss: 3.3516 - y1_output_root_mean_squared_error: 1.2084 - y2_output_root_mean_squared_error: 1.8337 - val_loss: 7.4031 - val_y1_output_loss: 1.6794 - val_y2_output_loss: 5.7546 - val_y1_output_root_mean_squared_error: 1.2996 - val_y2_output_root_mean_squared_error: 2.3904
# Epoch 75/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.1962 - y1_output_loss: 1.8591 - y2_output_loss: 5.2829 - y1_output_root_mean_squared_error: 1.3692 - y2_output_root_mean_squared_error: 2.3069 - val_loss: 5.3680 - val_y1_output_loss: 1.5909 - val_y2_output_loss: 3.8723 - val_y1_output_root_mean_squared_error: 1.2513 - val_y2_output_root_mean_squared_error: 1.9499
# Epoch 76/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.0443 - y1_output_loss: 1.4473 - y2_output_loss: 3.5577 - y1_output_root_mean_squared_error: 1.2076 - y2_output_root_mean_squared_error: 1.8936 - val_loss: 12.1374 - val_y1_output_loss: 3.7585 - val_y2_output_loss: 8.3590 - val_y1_output_root_mean_squared_error: 1.9518 - val_y2_output_root_mean_squared_error: 2.8858
# Epoch 77/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.0025 - y1_output_loss: 1.6884 - y2_output_loss: 3.2993 - y1_output_root_mean_squared_error: 1.3033 - y2_output_root_mean_squared_error: 1.8177 - val_loss: 6.5769 - val_y1_output_loss: 1.3018 - val_y2_output_loss: 5.2416 - val_y1_output_root_mean_squared_error: 1.1402 - val_y2_output_root_mean_squared_error: 2.2971
# Epoch 78/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.2810 - y1_output_loss: 1.7017 - y2_output_loss: 3.5494 - y1_output_root_mean_squared_error: 1.3106 - y2_output_root_mean_squared_error: 1.8877 - val_loss: 5.9389 - val_y1_output_loss: 1.5174 - val_y2_output_loss: 4.5900 - val_y1_output_root_mean_squared_error: 1.2068 - val_y2_output_root_mean_squared_error: 2.1172
# Epoch 79/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.5587 - y1_output_loss: 1.3992 - y2_output_loss: 3.1579 - y1_output_root_mean_squared_error: 1.1859 - y2_output_root_mean_squared_error: 1.7755 - val_loss: 9.0057 - val_y1_output_loss: 1.7192 - val_y2_output_loss: 7.2386 - val_y1_output_root_mean_squared_error: 1.3231 - val_y2_output_root_mean_squared_error: 2.6935
# Epoch 80/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.6406 - y1_output_loss: 1.3999 - y2_output_loss: 3.2487 - y1_output_root_mean_squared_error: 1.1858 - y2_output_root_mean_squared_error: 1.7984 - val_loss: 5.4154 - val_y1_output_loss: 1.1682 - val_y2_output_loss: 4.2009 - val_y1_output_root_mean_squared_error: 1.0884 - val_y2_output_root_mean_squared_error: 2.0569
# Epoch 81/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9299 - y1_output_loss: 1.2078 - y2_output_loss: 2.6869 - y1_output_root_mean_squared_error: 1.1043 - y2_output_root_mean_squared_error: 1.6464 - val_loss: 4.3081 - val_y1_output_loss: 1.0878 - val_y2_output_loss: 3.2651 - val_y1_output_root_mean_squared_error: 1.0370 - val_y2_output_root_mean_squared_error: 1.7980
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7135 - y1_output_loss: 1.0842 - y2_output_loss: 2.6301 - y1_output_root_mean_squared_error: 1.0369 - y2_output_root_mean_squared_error: 1.6243 - val_loss: 5.2846 - val_y1_output_loss: 1.4034 - val_y2_output_loss: 3.8513 - val_y1_output_root_mean_squared_error: 1.1959 - val_y2_output_root_mean_squared_error: 1.9633
# Epoch 83/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.5808 - y1_output_loss: 1.4710 - y2_output_loss: 3.1026 - y1_output_root_mean_squared_error: 1.2160 - y2_output_root_mean_squared_error: 1.7613 - val_loss: 5.4369 - val_y1_output_loss: 1.6350 - val_y2_output_loss: 3.8408 - val_y1_output_root_mean_squared_error: 1.2843 - val_y2_output_root_mean_squared_error: 1.9461
# Epoch 84/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7587 - y1_output_loss: 1.1357 - y2_output_loss: 2.6225 - y1_output_root_mean_squared_error: 1.0687 - y2_output_root_mean_squared_error: 1.6176 - val_loss: 4.4691 - val_y1_output_loss: 1.2975 - val_y2_output_loss: 3.1048 - val_y1_output_root_mean_squared_error: 1.1572 - val_y2_output_root_mean_squared_error: 1.7692
# Epoch 85/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0043 - y1_output_loss: 1.1151 - y2_output_loss: 2.8517 - y1_output_root_mean_squared_error: 1.0608 - y2_output_root_mean_squared_error: 1.6968 - val_loss: 4.0318 - val_y1_output_loss: 0.9503 - val_y2_output_loss: 3.0835 - val_y1_output_root_mean_squared_error: 0.9700 - val_y2_output_root_mean_squared_error: 1.7581
# Epoch 86/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.2259 - y1_output_loss: 1.1393 - y2_output_loss: 3.0497 - y1_output_root_mean_squared_error: 1.0711 - y2_output_root_mean_squared_error: 1.7546 - val_loss: 3.8184 - val_y1_output_loss: 0.8534 - val_y2_output_loss: 3.0303 - val_y1_output_root_mean_squared_error: 0.9154 - val_y2_output_root_mean_squared_error: 1.7264
# Epoch 87/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.6044 - y1_output_loss: 1.2523 - y2_output_loss: 3.5397 - y1_output_root_mean_squared_error: 1.1037 - y2_output_root_mean_squared_error: 1.8402 - val_loss: 66.9564 - val_y1_output_loss: 17.8530 - val_y2_output_loss: 50.2858 - val_y1_output_root_mean_squared_error: 4.1760 - val_y2_output_root_mean_squared_error: 7.0368
# Epoch 88/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.2465 - y1_output_loss: 1.8935 - y2_output_loss: 5.3499 - y1_output_root_mean_squared_error: 1.3803 - y2_output_root_mean_squared_error: 2.3111 - val_loss: 5.9688 - val_y1_output_loss: 1.0006 - val_y2_output_loss: 5.0607 - val_y1_output_root_mean_squared_error: 0.9933 - val_y2_output_root_mean_squared_error: 2.2321
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.6660 - y1_output_loss: 0.9455 - y2_output_loss: 2.7137 - y1_output_root_mean_squared_error: 0.9755 - y2_output_root_mean_squared_error: 1.6476 - val_loss: 6.0464 - val_y1_output_loss: 1.0579 - val_y2_output_loss: 4.8471 - val_y1_output_root_mean_squared_error: 1.0367 - val_y2_output_root_mean_squared_error: 2.2297
# Epoch 90/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.8969 - y1_output_loss: 1.3912 - y2_output_loss: 3.4636 - y1_output_root_mean_squared_error: 1.1841 - y2_output_root_mean_squared_error: 1.8695 - val_loss: 4.3539 - val_y1_output_loss: 1.1868 - val_y2_output_loss: 3.0742 - val_y1_output_root_mean_squared_error: 1.1043 - val_y2_output_root_mean_squared_error: 1.7705
# Epoch 91/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8488 - y1_output_loss: 0.7362 - y2_output_loss: 2.1639 - y1_output_root_mean_squared_error: 0.8607 - y2_output_root_mean_squared_error: 1.4519 - val_loss: 10.3130 - val_y1_output_loss: 2.0761 - val_y2_output_loss: 8.3191 - val_y1_output_root_mean_squared_error: 1.4248 - val_y2_output_root_mean_squared_error: 2.8780
# Epoch 92/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.7320 - y1_output_loss: 0.8200 - y2_output_loss: 1.9113 - y1_output_root_mean_squared_error: 0.9032 - y2_output_root_mean_squared_error: 1.3843 - val_loss: 5.1926 - val_y1_output_loss: 1.1906 - val_y2_output_loss: 3.9702 - val_y1_output_root_mean_squared_error: 1.1035 - val_y2_output_root_mean_squared_error: 1.9937
# Epoch 93/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.2299 - y1_output_loss: 1.0235 - y2_output_loss: 3.1782 - y1_output_root_mean_squared_error: 1.0134 - y2_output_root_mean_squared_error: 1.7896 - val_loss: 3.7321 - val_y1_output_loss: 0.6907 - val_y2_output_loss: 3.0013 - val_y1_output_root_mean_squared_error: 0.8448 - val_y2_output_root_mean_squared_error: 1.7373
# Epoch 94/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.3054 - y1_output_loss: 0.8762 - y2_output_loss: 2.4380 - y1_output_root_mean_squared_error: 0.9338 - y2_output_root_mean_squared_error: 1.5600 - val_loss: 10.2370 - val_y1_output_loss: 1.7520 - val_y2_output_loss: 8.3435 - val_y1_output_root_mean_squared_error: 1.3472 - val_y2_output_root_mean_squared_error: 2.9021
# Epoch 95/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.9175 - y1_output_loss: 1.3813 - y2_output_loss: 3.5227 - y1_output_root_mean_squared_error: 1.1802 - y2_output_root_mean_squared_error: 1.8774 - val_loss: 4.2398 - val_y1_output_loss: 0.9344 - val_y2_output_loss: 3.3528 - val_y1_output_root_mean_squared_error: 0.9535 - val_y2_output_root_mean_squared_error: 1.8250
# Epoch 96/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.5443 - y1_output_loss: 0.6598 - y2_output_loss: 1.8709 - y1_output_root_mean_squared_error: 0.8154 - y2_output_root_mean_squared_error: 1.3709 - val_loss: 3.8485 - val_y1_output_loss: 0.9692 - val_y2_output_loss: 2.8997 - val_y1_output_root_mean_squared_error: 0.9715 - val_y2_output_root_mean_squared_error: 1.7043
# Epoch 97/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7476 - y1_output_loss: 0.6612 - y2_output_loss: 2.0771 - y1_output_root_mean_squared_error: 0.8067 - y2_output_root_mean_squared_error: 1.4480 - val_loss: 4.3906 - val_y1_output_loss: 0.9767 - val_y2_output_loss: 3.3623 - val_y1_output_root_mean_squared_error: 1.0059 - val_y2_output_root_mean_squared_error: 1.8381
# Epoch 98/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7366 - y1_output_loss: 0.7149 - y2_output_loss: 2.1336 - y1_output_root_mean_squared_error: 0.8385 - y2_output_root_mean_squared_error: 1.4260 - val_loss: 23.6777 - val_y1_output_loss: 4.9645 - val_y2_output_loss: 19.5685 - val_y1_output_root_mean_squared_error: 2.1467 - val_y2_output_root_mean_squared_error: 4.3669
# Epoch 99/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9713 - y1_output_loss: 1.1817 - y2_output_loss: 2.8154 - y1_output_root_mean_squared_error: 1.0874 - y2_output_root_mean_squared_error: 1.6700 - val_loss: 6.9254 - val_y1_output_loss: 0.8641 - val_y2_output_loss: 5.9582 - val_y1_output_root_mean_squared_error: 0.9450 - val_y2_output_root_mean_squared_error: 2.4561
# Epoch 100/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6101 - y1_output_loss: 0.6222 - y2_output_loss: 2.0102 - y1_output_root_mean_squared_error: 0.7910 - y2_output_root_mean_squared_error: 1.4087 - val_loss: 4.9055 - val_y1_output_loss: 0.7346 - val_y2_output_loss: 4.1684 - val_y1_output_root_mean_squared_error: 0.8574 - val_y2_output_root_mean_squared_error: 2.0422
# Epoch 101/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6288 - y1_output_loss: 0.6006 - y2_output_loss: 2.0921 - y1_output_root_mean_squared_error: 0.7753 - y2_output_root_mean_squared_error: 1.4240 - val_loss: 4.2447 - val_y1_output_loss: 1.0309 - val_y2_output_loss: 3.2378 - val_y1_output_root_mean_squared_error: 0.9978 - val_y2_output_root_mean_squared_error: 1.8025
# Epoch 102/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3479 - y1_output_loss: 0.6139 - y2_output_loss: 1.7706 - y1_output_root_mean_squared_error: 0.7864 - y2_output_root_mean_squared_error: 1.3151 - val_loss: 10.0742 - val_y1_output_loss: 1.5867 - val_y2_output_loss: 8.5916 - val_y1_output_root_mean_squared_error: 1.2434 - val_y2_output_root_mean_squared_error: 2.9203
# Epoch 103/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8529 - y1_output_loss: 0.6160 - y2_output_loss: 2.2117 - y1_output_root_mean_squared_error: 0.7881 - y2_output_root_mean_squared_error: 1.4939 - val_loss: 2.9002 - val_y1_output_loss: 0.5254 - val_y2_output_loss: 2.3335 - val_y1_output_root_mean_squared_error: 0.7262 - val_y2_output_root_mean_squared_error: 1.5404
# Epoch 104/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.2146 - y1_output_loss: 0.7201 - y2_output_loss: 2.5274 - y1_output_root_mean_squared_error: 0.8475 - y2_output_root_mean_squared_error: 1.5800 - val_loss: 13.6343 - val_y1_output_loss: 1.7516 - val_y2_output_loss: 11.7150 - val_y1_output_root_mean_squared_error: 1.3462 - val_y2_output_root_mean_squared_error: 3.4383
# Epoch 105/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0160 - y1_output_loss: 0.7622 - y2_output_loss: 2.2695 - y1_output_root_mean_squared_error: 0.8747 - y2_output_root_mean_squared_error: 1.5003 - val_loss: 7.2930 - val_y1_output_loss: 1.1858 - val_y2_output_loss: 5.9455 - val_y1_output_root_mean_squared_error: 1.1082 - val_y2_output_root_mean_squared_error: 2.4627
# Epoch 106/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6172 - y1_output_loss: 0.5760 - y2_output_loss: 2.0249 - y1_output_root_mean_squared_error: 0.7601 - y2_output_root_mean_squared_error: 1.4281 - val_loss: 3.1347 - val_y1_output_loss: 0.5598 - val_y2_output_loss: 2.5093 - val_y1_output_root_mean_squared_error: 0.7526 - val_y2_output_root_mean_squared_error: 1.6026
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9031 - y1_output_loss: 0.7648 - y2_output_loss: 2.1592 - y1_output_root_mean_squared_error: 0.8696 - y2_output_root_mean_squared_error: 1.4652 - val_loss: 7.2300 - val_y1_output_loss: 2.5020 - val_y2_output_loss: 4.7066 - val_y1_output_root_mean_squared_error: 1.5979 - val_y2_output_root_mean_squared_error: 2.1625
# Epoch 108/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2222 - y1_output_loss: 0.5497 - y2_output_loss: 1.6554 - y1_output_root_mean_squared_error: 0.7433 - y2_output_root_mean_squared_error: 1.2922 - val_loss: 3.0983 - val_y1_output_loss: 0.5241 - val_y2_output_loss: 2.5151 - val_y1_output_root_mean_squared_error: 0.7344 - val_y2_output_root_mean_squared_error: 1.5997
# Epoch 109/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4533 - y1_output_loss: 0.6444 - y2_output_loss: 1.8200 - y1_output_root_mean_squared_error: 0.8025 - y2_output_root_mean_squared_error: 1.3451 - val_loss: 3.9012 - val_y1_output_loss: 0.9993 - val_y2_output_loss: 2.8922 - val_y1_output_root_mean_squared_error: 0.9919 - val_y2_output_root_mean_squared_error: 1.7080
# Epoch 110/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.3453 - y1_output_loss: 1.2076 - y2_output_loss: 3.1521 - y1_output_root_mean_squared_error: 1.1005 - y2_output_root_mean_squared_error: 1.7703 - val_loss: 8.8102 - val_y1_output_loss: 1.0001 - val_y2_output_loss: 7.9311 - val_y1_output_root_mean_squared_error: 0.9789 - val_y2_output_root_mean_squared_error: 2.8021
# Epoch 111/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1288 - y1_output_loss: 0.7778 - y2_output_loss: 2.3276 - y1_output_root_mean_squared_error: 0.8849 - y2_output_root_mean_squared_error: 1.5316 - val_loss: 3.9428 - val_y1_output_loss: 1.0596 - val_y2_output_loss: 2.8356 - val_y1_output_root_mean_squared_error: 1.0432 - val_y2_output_root_mean_squared_error: 1.6895
# Epoch 112/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.0408 - y1_output_loss: 1.0469 - y2_output_loss: 2.9921 - y1_output_root_mean_squared_error: 1.0278 - y2_output_root_mean_squared_error: 1.7276 - val_loss: 8.1006 - val_y1_output_loss: 1.9331 - val_y2_output_loss: 6.7076 - val_y1_output_root_mean_squared_error: 1.3003 - val_y2_output_root_mean_squared_error: 2.5318
# Epoch 113/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5885 - y1_output_loss: 0.7638 - y2_output_loss: 2.8112 - y1_output_root_mean_squared_error: 0.8775 - y2_output_root_mean_squared_error: 1.6789 - val_loss: 4.2457 - val_y1_output_loss: 0.7514 - val_y2_output_loss: 3.3990 - val_y1_output_root_mean_squared_error: 0.8769 - val_y2_output_root_mean_squared_error: 1.8646
# Epoch 114/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.4823 - y1_output_loss: 0.6535 - y2_output_loss: 1.8217 - y1_output_root_mean_squared_error: 0.8088 - y2_output_root_mean_squared_error: 1.3521 - val_loss: 3.6911 - val_y1_output_loss: 1.0668 - val_y2_output_loss: 2.6630 - val_y1_output_root_mean_squared_error: 1.0007 - val_y2_output_root_mean_squared_error: 1.6400
# Epoch 115/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4367 - y1_output_loss: 0.6383 - y2_output_loss: 1.8007 - y1_output_root_mean_squared_error: 0.8010 - y2_output_root_mean_squared_error: 1.3398 - val_loss: 4.4860 - val_y1_output_loss: 0.9788 - val_y2_output_loss: 3.3921 - val_y1_output_root_mean_squared_error: 1.0017 - val_y2_output_root_mean_squared_error: 1.8662
# Epoch 116/500
# 614/614 [==============================] - 0s 155us/sample - loss: 1.9064 - y1_output_loss: 0.4721 - y2_output_loss: 1.4282 - y1_output_root_mean_squared_error: 0.6858 - y2_output_root_mean_squared_error: 1.1984 - val_loss: 3.1343 - val_y1_output_loss: 0.7451 - val_y2_output_loss: 2.3884 - val_y1_output_root_mean_squared_error: 0.8513 - val_y2_output_root_mean_squared_error: 1.5523
# Epoch 117/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.8579 - y1_output_loss: 0.7117 - y2_output_loss: 2.1464 - y1_output_root_mean_squared_error: 0.8455 - y2_output_root_mean_squared_error: 1.4639 - val_loss: 3.9363 - val_y1_output_loss: 0.6557 - val_y2_output_loss: 3.2682 - val_y1_output_root_mean_squared_error: 0.8018 - val_y2_output_root_mean_squared_error: 1.8148
# Epoch 118/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.6662 - y1_output_loss: 0.6856 - y2_output_loss: 1.9743 - y1_output_root_mean_squared_error: 0.8276 - y2_output_root_mean_squared_error: 1.4076 - val_loss: 4.7212 - val_y1_output_loss: 1.0246 - val_y2_output_loss: 3.6881 - val_y1_output_root_mean_squared_error: 1.0184 - val_y2_output_root_mean_squared_error: 1.9194
# Epoch 119/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.3664 - y1_output_loss: 0.8571 - y2_output_loss: 2.4826 - y1_output_root_mean_squared_error: 0.9298 - y2_output_root_mean_squared_error: 1.5817 - val_loss: 2.5602 - val_y1_output_loss: 0.4753 - val_y2_output_loss: 2.0296 - val_y1_output_root_mean_squared_error: 0.7007 - val_y2_output_root_mean_squared_error: 1.4385
# Epoch 120/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.9868 - y1_output_loss: 0.3662 - y2_output_loss: 0.6132 - y1_output_root_mean_squared_error: 0.6075 - y2_output_root_mean_squared_error: 0.7860 - val_loss: 1.0698 - val_y1_output_loss: 0.3006 - val_y2_output_loss: 0.7652 - val_y1_output_root_mean_squared_error: 0.5382 - val_y2_output_root_mean_squared_error: 0.8833
# Epoch 462/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3501 - y1_output_loss: 0.1128 - y2_output_loss: 0.2395 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.4879 - val_loss: 1.3613 - val_y1_output_loss: 0.2425 - val_y2_output_loss: 1.1156 - val_y1_output_root_mean_squared_error: 0.4878 - val_y2_output_root_mean_squared_error: 1.0599
# Epoch 463/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5061 - y1_output_loss: 0.1384 - y2_output_loss: 0.3660 - y1_output_root_mean_squared_error: 0.3724 - y2_output_root_mean_squared_error: 0.6062 - val_loss: 1.4793 - val_y1_output_loss: 0.3311 - val_y2_output_loss: 1.1472 - val_y1_output_root_mean_squared_error: 0.5861 - val_y2_output_root_mean_squared_error: 1.0657
# Epoch 464/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4882 - y1_output_loss: 0.1535 - y2_output_loss: 0.3358 - y1_output_root_mean_squared_error: 0.3934 - y2_output_root_mean_squared_error: 0.5775 - val_loss: 1.1910 - val_y1_output_loss: 0.2342 - val_y2_output_loss: 0.9787 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.9826
# Epoch 465/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4102 - y1_output_loss: 0.1193 - y2_output_loss: 0.2916 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5388 - val_loss: 1.1013 - val_y1_output_loss: 0.3334 - val_y2_output_loss: 0.7771 - val_y1_output_root_mean_squared_error: 0.5642 - val_y2_output_root_mean_squared_error: 0.8848
# Epoch 466/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4552 - y1_output_loss: 0.1270 - y2_output_loss: 0.3254 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5722 - val_loss: 1.0145 - val_y1_output_loss: 0.2493 - val_y2_output_loss: 0.7687 - val_y1_output_root_mean_squared_error: 0.4993 - val_y2_output_root_mean_squared_error: 0.8748
# Epoch 467/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4623 - y1_output_loss: 0.1182 - y2_output_loss: 0.3408 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5864 - val_loss: 0.8215 - val_y1_output_loss: 0.2142 - val_y2_output_loss: 0.6131 - val_y1_output_root_mean_squared_error: 0.4561 - val_y2_output_root_mean_squared_error: 0.7833
# Epoch 468/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3089 - y1_output_loss: 0.1125 - y2_output_loss: 0.1967 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4436 - val_loss: 0.8818 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 0.6543 - val_y1_output_root_mean_squared_error: 0.4753 - val_y2_output_root_mean_squared_error: 0.8099
# Epoch 469/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4417 - y1_output_loss: 0.1366 - y2_output_loss: 0.3097 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5518 - val_loss: 1.8238 - val_y1_output_loss: 0.2748 - val_y2_output_loss: 1.5625 - val_y1_output_root_mean_squared_error: 0.5201 - val_y2_output_root_mean_squared_error: 1.2463
# Epoch 470/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3330 - y1_output_loss: 0.1155 - y2_output_loss: 0.2163 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 0.8444 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.6475 - val_y1_output_root_mean_squared_error: 0.4510 - val_y2_output_root_mean_squared_error: 0.8006
# Epoch 471/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3682 - y1_output_loss: 0.1076 - y2_output_loss: 0.2586 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.5102 - val_loss: 0.8528 - val_y1_output_loss: 0.2083 - val_y2_output_loss: 0.6401 - val_y1_output_root_mean_squared_error: 0.4628 - val_y2_output_root_mean_squared_error: 0.7992
# Epoch 472/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4016 - y1_output_loss: 0.1365 - y2_output_loss: 0.2623 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.5143 - val_loss: 0.9854 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 0.7880 - val_y1_output_root_mean_squared_error: 0.4572 - val_y2_output_root_mean_squared_error: 0.8811
# Epoch 473/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3768 - y1_output_loss: 0.1152 - y2_output_loss: 0.2591 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.8482 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.6343 - val_y1_output_root_mean_squared_error: 0.4596 - val_y2_output_root_mean_squared_error: 0.7981
# Epoch 474/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4747 - y1_output_loss: 0.1171 - y2_output_loss: 0.3540 - y1_output_root_mean_squared_error: 0.3427 - y2_output_root_mean_squared_error: 0.5977 - val_loss: 0.8145 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 0.6010 - val_y1_output_root_mean_squared_error: 0.4586 - val_y2_output_root_mean_squared_error: 0.7773
# Epoch 475/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5087 - y1_output_loss: 0.1223 - y2_output_loss: 0.3831 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.6207 - val_loss: 0.9478 - val_y1_output_loss: 0.2498 - val_y2_output_loss: 0.6892 - val_y1_output_root_mean_squared_error: 0.5041 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 476/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3491 - y1_output_loss: 0.1193 - y2_output_loss: 0.2274 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.4787 - val_loss: 0.8700 - val_y1_output_loss: 0.2731 - val_y2_output_loss: 0.6026 - val_y1_output_root_mean_squared_error: 0.5063 - val_y2_output_root_mean_squared_error: 0.7834
# Epoch 477/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3868 - y1_output_loss: 0.1167 - y2_output_loss: 0.2679 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 0.9026 - val_y1_output_loss: 0.2107 - val_y2_output_loss: 0.6978 - val_y1_output_root_mean_squared_error: 0.4585 - val_y2_output_root_mean_squared_error: 0.8321
# Epoch 478/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4060 - y1_output_loss: 0.1264 - y2_output_loss: 0.2784 - y1_output_root_mean_squared_error: 0.3557 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 0.8524 - val_y1_output_loss: 0.2257 - val_y2_output_loss: 0.6226 - val_y1_output_root_mean_squared_error: 0.4720 - val_y2_output_root_mean_squared_error: 0.7935
# Epoch 479/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4375 - y1_output_loss: 0.1184 - y2_output_loss: 0.3211 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5677 - val_loss: 1.8428 - val_y1_output_loss: 0.7270 - val_y2_output_loss: 1.1804 - val_y1_output_root_mean_squared_error: 0.8200 - val_y2_output_root_mean_squared_error: 1.0818
# Epoch 480/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3427 - y1_output_loss: 0.1183 - y2_output_loss: 0.2217 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.4731 - val_loss: 0.8423 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 0.6280 - val_y1_output_root_mean_squared_error: 0.4571 - val_y2_output_root_mean_squared_error: 0.7958
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3988 - y1_output_loss: 0.0963 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3110 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 0.9040 - val_y1_output_loss: 0.2011 - val_y2_output_loss: 0.7110 - val_y1_output_root_mean_squared_error: 0.4530 - val_y2_output_root_mean_squared_error: 0.8359
# Epoch 482/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.5402 - y1_output_loss: 0.1790 - y2_output_loss: 0.3765 - y1_output_root_mean_squared_error: 0.4138 - y2_output_root_mean_squared_error: 0.6075 - val_loss: 3.6162 - val_y1_output_loss: 1.5673 - val_y2_output_loss: 2.1739 - val_y1_output_root_mean_squared_error: 1.2124 - val_y2_output_root_mean_squared_error: 1.4650
# Epoch 483/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.9075 - y1_output_loss: 0.3046 - y2_output_loss: 0.5972 - y1_output_root_mean_squared_error: 0.5533 - y2_output_root_mean_squared_error: 0.7755 - val_loss: 0.9292 - val_y1_output_loss: 0.2389 - val_y2_output_loss: 0.6824 - val_y1_output_root_mean_squared_error: 0.4874 - val_y2_output_root_mean_squared_error: 0.8316
# Epoch 484/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3934 - y1_output_loss: 0.1265 - y2_output_loss: 0.2764 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.5187 - val_loss: 2.4320 - val_y1_output_loss: 0.8813 - val_y2_output_loss: 1.6319 - val_y1_output_root_mean_squared_error: 0.9067 - val_y2_output_root_mean_squared_error: 1.2688
# Epoch 485/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3445 - y1_output_loss: 0.1095 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.4842 - val_loss: 0.9880 - val_y1_output_loss: 0.2096 - val_y2_output_loss: 0.7757 - val_y1_output_root_mean_squared_error: 0.4625 - val_y2_output_root_mean_squared_error: 0.8798
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3852 - y1_output_loss: 0.1112 - y2_output_loss: 0.2723 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.5232 - val_loss: 0.8194 - val_y1_output_loss: 0.2069 - val_y2_output_loss: 0.6087 - val_y1_output_root_mean_squared_error: 0.4537 - val_y2_output_root_mean_squared_error: 0.7833
# Epoch 487/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4951 - y1_output_loss: 0.1398 - y2_output_loss: 0.3513 - y1_output_root_mean_squared_error: 0.3754 - y2_output_root_mean_squared_error: 0.5951 - val_loss: 1.0926 - val_y1_output_loss: 0.2896 - val_y2_output_loss: 0.8057 - val_y1_output_root_mean_squared_error: 0.5369 - val_y2_output_root_mean_squared_error: 0.8968
# Epoch 488/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.7076 - y1_output_loss: 0.1786 - y2_output_loss: 0.5232 - y1_output_root_mean_squared_error: 0.4238 - y2_output_root_mean_squared_error: 0.7266 - val_loss: 1.1681 - val_y1_output_loss: 0.2757 - val_y2_output_loss: 0.8872 - val_y1_output_root_mean_squared_error: 0.5327 - val_y2_output_root_mean_squared_error: 0.9404
# Epoch 489/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3135 - y1_output_loss: 0.1011 - y2_output_loss: 0.2141 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4630 - val_loss: 0.8919 - val_y1_output_loss: 0.2736 - val_y2_output_loss: 0.6207 - val_y1_output_root_mean_squared_error: 0.5195 - val_y2_output_root_mean_squared_error: 0.7887
# Epoch 490/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3311 - y1_output_loss: 0.1101 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.4694 - val_loss: 0.9230 - val_y1_output_loss: 0.3313 - val_y2_output_loss: 0.6004 - val_y1_output_root_mean_squared_error: 0.5625 - val_y2_output_root_mean_squared_error: 0.7789
# Epoch 491/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3610 - y1_output_loss: 0.1066 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.5038 - val_loss: 1.3782 - val_y1_output_loss: 0.2438 - val_y2_output_loss: 1.1376 - val_y1_output_root_mean_squared_error: 0.4867 - val_y2_output_root_mean_squared_error: 1.0683
# Epoch 492/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.7571 - y1_output_loss: 0.1926 - y2_output_loss: 0.5585 - y1_output_root_mean_squared_error: 0.4406 - y2_output_root_mean_squared_error: 0.7503 - val_loss: 0.8770 - val_y1_output_loss: 0.2678 - val_y2_output_loss: 0.5950 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.7748
# Epoch 493/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3697 - y1_output_loss: 0.1206 - y2_output_loss: 0.2463 - y1_output_root_mean_squared_error: 0.3487 - y2_output_root_mean_squared_error: 0.4981 - val_loss: 0.8185 - val_y1_output_loss: 0.2236 - val_y2_output_loss: 0.5898 - val_y1_output_root_mean_squared_error: 0.4714 - val_y2_output_root_mean_squared_error: 0.7722
# Epoch 494/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3951 - y1_output_loss: 0.1307 - y2_output_loss: 0.2647 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.5150 - val_loss: 0.8427 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.6196 - val_y1_output_root_mean_squared_error: 0.4749 - val_y2_output_root_mean_squared_error: 0.7856
# Epoch 495/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4000 - y1_output_loss: 0.1404 - y2_output_loss: 0.2612 - y1_output_root_mean_squared_error: 0.3754 - y2_output_root_mean_squared_error: 0.5090 - val_loss: 1.8896 - val_y1_output_loss: 0.2147 - val_y2_output_loss: 1.6702 - val_y1_output_root_mean_squared_error: 0.4692 - val_y2_output_root_mean_squared_error: 1.2921
# Epoch 496/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3131 - y1_output_loss: 0.1166 - y2_output_loss: 0.1955 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.4424 - val_loss: 1.4042 - val_y1_output_loss: 0.2454 - val_y2_output_loss: 1.1784 - val_y1_output_root_mean_squared_error: 0.5038 - val_y2_output_root_mean_squared_error: 1.0726
# Epoch 497/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3690 - y1_output_loss: 0.1199 - y2_output_loss: 0.2493 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.4996 - val_loss: 0.9582 - val_y1_output_loss: 0.3497 - val_y2_output_loss: 0.6249 - val_y1_output_root_mean_squared_error: 0.5721 - val_y2_output_root_mean_squared_error: 0.7943
# Epoch 498/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3474 - y1_output_loss: 0.1281 - y2_output_loss: 0.2207 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.4697 - val_loss: 1.1622 - val_y1_output_loss: 0.2810 - val_y2_output_loss: 0.8859 - val_y1_output_root_mean_squared_error: 0.5391 - val_y2_output_root_mean_squared_error: 0.9335
# Epoch 499/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2864 - y1_output_loss: 0.1023 - y2_output_loss: 0.1822 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.4288 - val_loss: 0.8530 - val_y1_output_loss: 0.2822 - val_y2_output_loss: 0.5755 - val_y1_output_root_mean_squared_error: 0.5144 - val_y2_output_root_mean_squared_error: 0.7671
# Epoch 500/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3040 - y1_output_loss: 0.1071 - y2_output_loss: 0.1954 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.4438 - val_loss: 0.8223 - val_y1_output_loss: 0.2211 - val_y2_output_loss: 0.5944 - val_y1_output_root_mean_squared_error: 0.4779 - val_y2_output_root_mean_squared_error: 0.7707

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.8223 - y1_output_loss: 0.2255 - y2_output_loss: 0.5992 - y1_output_root_mean_squared_error: 0.4779 - y2_output_root_mean_squared_error: 0.7707
# Loss = 0.8223175940575538, Y1_loss = 0.22550439834594727, Y1_mse = 0.477888822555542, Y2_loss = 0.5991643667221069, Y2_mse = 0.7706749439239502

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
